# %%
import pandas as pd
import os

# %%
pwd
# Out:
# '/Users/bertrumfoster/Downloads'

# %%
df = pd.read_csv('higher_ed_dataset.csv', encoding ='latin1')
pd.set_option('display.max_columns', None)
df
# Out:
#        unitid                                           instname         ay  \
# 0      100654                           Alabama A & M University  2008-2009
# 1      100654                           Alabama A & M University  2009-2010
# 2      100654                           Alabama A & M University  2010-2011
# 3      100654                           Alabama A & M University  2011-2012
# 4      100654                           Alabama A & M University  2012-2013
# 5      100654                           Alabama A & M University  2013-2014
# 6      100654                           Alabama A & M University  2014-2015
# 7      100654                           Alabama A & M University  2015-2016
# 8      100654                           Alabama A & M University  2016-2017
# 9      100654                           Alabama A & M University  2017-2018
# 10     100663                University of Alabama at Birmingham  2008-2009
# ...

# %%
df.isnull().sum()
# Out:
# unitid                                      0
# instname                                    0
# ay                                          0
# percent_ft_ug_aid                        7770
# percent_ft_ug_inst_aid                   7792
# percent_ft_ug_pell_aid                   7792
# avg_np_stdnts_aid_current_yr_public     24600
# avg_np_stdnts_aid_prior_1_yr_public     24625
# avg_np_stdnts_aid_prior_2_yr_public     24649
# avg_np_stdnts_aid_current_yr_private    15367
# avg_np_stdnts_aid_prior_1_yr_private    15743
# avg_np_stdnts_aid_prior_2_yr_private    15987
# stabbr                                   2770
# sector                                   2770
# instsize                                 2770
# city                                     2779
# zip                                      2779
# closedat                                 2770
# pub_in_state_tuition_fees                7792
# pub_out_state_tuition_fees               7792
# ...

# %%
df.corr()
# Out:
#                                         unitid  percent_ft_ug_aid  \
# unitid                                1.000000          -0.096347
# percent_ft_ug_aid                    -0.096347           1.000000
# percent_ft_ug_inst_aid               -0.285380           0.496881
# percent_ft_ug_pell_aid                0.257602           0.374545
# avg_np_stdnts_aid_current_yr_public  -0.017972           0.191109
# avg_np_stdnts_aid_prior_1_yr_public  -0.011990           0.182211
# avg_np_stdnts_aid_prior_2_yr_public  -0.009903           0.175867
# avg_np_stdnts_aid_current_yr_private -0.098702          -0.071065
# avg_np_stdnts_aid_prior_1_yr_private -0.083404          -0.081310
# avg_np_stdnts_aid_prior_2_yr_private -0.068108          -0.084103
# sector                                0.194809          -0.011984
# instsize                             -0.296004          -0.154083
# pub_in_state_tuition_fees            -0.147530           0.138287
# ...

# %%
df.columns
# Out:
# Index(['unitid', 'instname', 'ay', 'percent_ft_ug_aid',
#        'percent_ft_ug_inst_aid', 'percent_ft_ug_pell_aid',
#        'avg_np_stdnts_aid_current_yr_public',
#        'avg_np_stdnts_aid_prior_1_yr_public',
#        'avg_np_stdnts_aid_prior_2_yr_public',
#        'avg_np_stdnts_aid_current_yr_private',
#        ...
#        'equity_ratio_gasb', 'equity_ratio_fasb', 'ug_enrollment',
#        'grad_enrollment', 'num_first_time_ug_in_state',
#        'num_first_time_ug_out_state', 'perc_first_time_ug_out_state',
#        'perc_first_time_ug_in_state', 'sector_desc', 'instsize_descr'],
#       dtype='object', length=102)

# %%
df['closedat'].isnull().sum()
# Out:
# 2770
